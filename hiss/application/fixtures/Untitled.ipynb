# %%
import json

# %%
with open('schools.json', 'r') as o:
    schools = json.load(o)

# %%
o = open('schools.json', 'r')

# %%
schools = json.load(o)

# %%
schools
# Out:
# [{'model': 'application.school',
#   'pk': 1565,
#   'fields': {'name': 'Texas A&M University'}},
#  {'model': 'application.school',
#   'pk': 1,
#   'fields': {'name': 'Academy of Art College'}},
#  {'model': 'application.school',
#   'pk': 2,
#   'fields': {'name': 'Adams State College'}},
#  {'model': 'application.school',
#   'pk': 3,
#   'fields': {'name': 'Adelphi University'}},
#  {'model': 'application.school',
#   'pk': 4,
#   'fields': {'name': 'Adler School of Professional Psychology'}},
#  {'model': 'application.school',
#   'pk': 5,
#   'fields': {'name': 'Adrian College'}},
#  {'model': 'application.school',
#   'pk': 6,
#   'fields': {'name': 'Agnes Scott College'}},
#  {'model': 'application.school',
#   'pk': 7,
#   'fields': {'name': 'Air Force Institute of Technology'}},
#  {'model': 'application.school',
#   'pk': 8,
#   'fields': {'name': 'Alabama Agricultural and Mechanical University'}},
#  {'model': 'application.school',
#   'pk': 9,
# ...

# %%
schools[0]
# Out:
# {'model': 'application.school',
#  'pk': 1565,
#  'fields': {'name': 'Texas A&M University'}}

# %%
for school in schools:
    if school['pk'] > 1570:
        print(school)
        school['pk'] = school['pk'] + 1
# Out:
# {'model': 'application.school', 'pk': 2076, 'fields': {'name': 'Texas A&M University - San Antonio'}}
# {'model': 'application.school', 'pk': 1572, 'fields': {'name': 'Texas Chiropractic College'}}
# {'model': 'application.school', 'pk': 1573, 'fields': {'name': 'Texas Christian University'}}
# {'model': 'application.school', 'pk': 1574, 'fields': {'name': 'Texas College'}}
# {'model': 'application.school', 'pk': 1575, 'fields': {'name': 'Texas College of Osteopathic Medicine'}}
# {'model': 'application.school', 'pk': 1576, 'fields': {'name': 'Texas Lutheran University'}}
# {'model': 'application.school', 'pk': 1577, 'fields': {'name': 'Texas Southern University'}}
# {'model': 'application.school', 'pk': 1578, 'fields': {'name': 'Texas Tech University'}}
# {'model': 'application.school', 'pk': 1579, 'fields': {'name': 'Texas Tech University Health Science Center'}}
# {'model': 'application.school', 'pk': 1580, 'fields': {'name': 'Texas Wesleyan University'}}
# ...

# %%
with open('temp.json', 'w') as output:
    json.dump(schools, output)
